# %% [markdown]
# %md #Core Programming Concept

# %% [markdown]
# ##Types of varibles

# %%
#Integer 
x = 2

# %%
x

# %%
type(x)

# %%
#float / double 
y = 2.5

# %%
y

# %%
type(y)

# %%
# string
a = "hello"

# %%
a

# %%
type(a)

# %%
# logical
q1 = True

# %%
q1

# %%
type(q1)

# %% [markdown]
# ##Using Variables

# %%
A = 10
B = 20

# %%
C = A+B
D = B/A

# %%
print( C)
print(D)

# %%
import math

# %%
math.sqrt(A)
round(math.sqrt(A))

# %%
greeting = "Hello"
name = "Bob"
msg = greeting +' '+name
print(msg)

# %% [markdown]
# ##Boolean Variable and Operation

# %% [markdown]
# #### True  False

# %%
4 < 5

# %%
10 > 100

# %%
4==5

# %%
4 <> 5

# %%
4 != 5

# %% [markdown]
# ### opreator == != <>  > <= and or not

# %%
result = 4 <5 
result

# %%
type(result)

# %%
result2 = not(5 >1 )

# %%
result2

# %%
result or result2

# %%
result and result2
